# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
# Out:
# C:\Users\Abdulrhman Alsir\AppData\Local\Temp\ipykernel_960\1166095182.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd # primary data structure library

# %%
df_can = pd.read_csv('Clean Canada Dataset.csv')

print('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_can.index.name = None
df_can.head()
# tip: You can specify the number of rows you'd like to see as follows: df_can.head(10)
# Out:
#                                                            Continent  \
# Philippines                                                     Asia
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# United States of America                            Northern America
#
#                                                                 Region  \
# Philippines                                         South-Eastern Asia
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# United States of America                              Northern America
#
#                                                                DevName   1980  \
# ...

# %%
df_can.set_index('Country', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()

# %%
#let's check
df_can.head(3)

# %%
# optional: to remove the name of the index
df_can.index.name = None

# %%
# useful for plotting later on
years = list(map(str, range(1980, 2014)))
years

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print('Matplotlib version: ', mpl.__version__)  # >= 2.0.0
# Out:
# Matplotlib version:  3.8.2

# %%
print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#Since we converted the years to string, 
#let's declare a variable that will allow us to easily call upon the full range of years:
years = list(map(str, range(1980, 2014)))
#creating data series
haiti = df_can.loc['Haiti', years] # passing in years 1980 - 2013 to exclude the 'total' column
haiti.head().to_frame()
# Out:
#      Haiti
# 1980  1666
# 1981  3692
# 1982  3498
# 1983  2860
# 1984  1418

# %%
haiti.plot()
# Out:
# <Axes: >

# %%
haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure

# %%
haiti.index = haiti.index.map(int) 
haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

# annotate the 2010 Earthquake. 
# syntax: plt.text(x, y, label)
plt.text(2001, 6400, '2010 Earthquake') # see note below

plt.show()

# %%
### type your answer here

df_CI = df_can.loc[['China', 'India'], years]
df_CI
# Out:
#        1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# China  5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India  8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#         2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# China  36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India  28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
df_CI = df_CI.transpose()
df_CI.head()
# Out:
#       China  India
# 1980   5123   8880
# 1981   6682   8670
# 1982   3308   8147
# 1983   1863   7338
# 1984   1527   5704

# %%
### type your answer here
df_CI.index = df_CI.index.map(int)
df_CI.plot(kind='line')
plt.title('Immigration Trends from China and India to Canada 1980 - 2013')
plt.xlabel('Years')
plt.ylabel('Immigrants')
plt.show()

# %%
### type your answer here
df = df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)
df = df_can.head()
df = df[years].transpose()
df.index = df.index.map(int)
df.plot(kind='line', legend=True, figsize=(14, 8))
plt.title('Top 5 countries contribuing to immigration to Canada')
plt.xlabel('Years')
plt.ylabel('No. of Immingrant')
plt.show()
